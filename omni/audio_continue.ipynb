# %%
from infer import Infer
import IPython.display as ipd

# %%
model = Infer('/home/apurva/Downloads/multitask_gpt.pt')

# %%
from silero_vad import read_audio
import torch 

waveform = read_audio('/home/apurva/Downloads/rec1.flac', sampling_rate=24000)
with torch.inference_mode() as ctx:
    tokens = model.model.encode(waveform.reshape(1,1,-1), padding_mask=None)

# %%
waveform.shape[0]/24000

# %%
tokens = tokens['audio_codes']

# %%
from train_with_mimi import codebook_encoding

# %%
flat_tokens = codebook_encoding(tokens[0,:4,:].numpy(), per_codebook_size=2048)

# %%
audio = model.audio_infer(flat_tokens[:100])

# %%
ipd.Audio(audio[0][0], rate=24000)

# %%
ipd.Audio(waveform, rate=24000)

# %%
from hfload import convert_to_hf

hf_model = convert_to_hf('/home/apurva/Downloads/multitask_gpt.pt')

# %%
hf_model.push_to_hub(
        repo_id='cmeraki/hf-audio-continue',
        token='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',
        commit_message='speaker mashup model'
    )

model.text_tokenizer.tokenizer.push_to_hub(
    repo_id='cmeraki/hf-audio-continue',
    token='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',
    commit_message='speaker mashup model'
)
