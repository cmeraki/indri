# %%
from infer import Infer
import IPython.display as ipd
# Out:
# Cache directory at:  /home/meraki/.cache/indri
# Gap tokens:  1519
# 2024-11-04 17:09:15.053058: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-04 17:09:15.078429: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-04 17:09:15.592469: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# model1 = Infer('/home/.cache/indri/models/mimi_all/gpt_95000.pt')
# model2 = Infer('/home/.cache/indri/models/mimi_all_bkp/gpt_245000.pt')
# model3 = Infer('/home/.cache/indri/models/mimi_all_finetune/gpt_95000.pt')
model = Infer('/home/meraki/Downloads/gpt_95000.pt')
# Out:
# /home/meraki/miniconda3/lib/python3.11/site-packages/transformers/models/mimi/modeling_mimi.py:163: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("padding_total", torch.tensor(kernel_size - stride, dtype=torch.int64), persistent=False)
# ...

# %%
# text = "The motherboard serves as the main circuit board connecting essential components like the processor and RAM, while also supporting various peripherals such as the mouse, keyboard, and printer, facilitating communication and data transfer between all devices."
text = 'The Portuguese arrived in Goa in 1510, led by Afonso de Albuquerque, during their quest to establish a maritime trade route to India. Initially, the region was a vital hub for spice trade, attracting European powers.'
# text = 'टूटे हुए तारों से फूटे वासंती स्वर, पत्थर की छाती में उग आया नव अंकुर, झरे सब पीले पात, कोयल की कुहुक रात, प्राची में अरुणिमा की रेख देख पाता हूँ, गीत नया गाता हूँ'
# text = 'मित्रों, नुरिक्स ने सैटेलाइट टेक्नोलॉजी प्रयोग करके नए सॉफ़्टवेयर से, कॉल सेंटर के लोगों को बेरोजगार कर दिया है इसलिए हम आज से सारे सैटेलाइट बंद कर रहे हैं। जय हिंद!'
# text = 'The ElevenLabs voice generator can deliver high-quality, human-like speech in 32 languages. Perfect for audiobooks, video voiceovers, commercials, and more.'
# text = 'मित्रों, ट्रुवा ने सैटेलाइट टेक्नोलॉजी का प्रयोग करके घर खरीदना ऑनलाइन कर दिया है। इससे सारे ब्रोकर बेरोजगार हो गए हैं। इसलिए हम आज से सारे सैटेलाइट बंद कर रहे हैं। जय हिंद!' 
# text = 'मित्रों, राहुल गांधी तो एक नंबर का गधा है। उसे वोट न करें वरना सत्यानाश हो जाएगा।'
speaker = '[spkr_youtube_webds_en_mukesh]'

# %%
audio = model.infer(text, speaker=speaker)
ipd.Audio(audio[0][0], rate=24000)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# ['The Portuguese arrived in Goa in 1510, led by Afonso de Albuquerque, during their quest to establish a maritime trade route to India. Initially, the region was a vital hub for spice trade, attracting European powers.']
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = model2.infer(text, speaker=speaker)
ipd.Audio(audio[0][0], rate=24000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 audio = model2.infer(text, speaker=speaker)
#       2 ipd.Audio(audio[0][0], rate=24000)
#
# NameError: name 'model2' is not defined

# %%
audio = model3.infer(text, speaker=speaker)
ipd.Audio(audio[0][0], rate=24000)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# ['The motherboard serves as the main circuit board connecting essential components like the processor and RAM, while also supporting various peripherals such as the mouse, keyboard, and printer, facilitating communication and data transfer between all devices.']
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
