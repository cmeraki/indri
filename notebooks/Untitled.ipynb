# %% [markdown]
# - numpy load
# - flac/opus edit
#
# - try/except in batching

# %%
import numpy as np
from pathlib import Path
from tqdm import tqdm

# %%
fls = Path('/home/.cache/indri/data/gs_xl_en_tokens/tokens').glob('**/*.npy')
errors = []

for f in tqdm(fls):
    try:
        np.load(f)
    except:
        errors.append(f)
# Out:
# 12046169it [3:50:40, 2157.32it/s]

# %%
len(errors)
