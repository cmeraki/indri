# %%
from transformers import AutoTokenizer

# %%
tkz = AutoTokenizer.from_pretrained('cmeraki/gpt2-124M-400B')

# %%
tkz.add_special_tokens({'additional_special_tokens': ['[stop]', '[continue]', '[convert]']})
# Out:
# 1

# %%
tkz.encode('[convert]')
# Out:
# [50259]

# %%
tkz.decode(50259)
# Out:
# '[convert]'

# %%
tkz.add_tokens('[text]')
# Out:
# 1
